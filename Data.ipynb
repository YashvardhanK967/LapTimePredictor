# %%
# !pip install fastf1 pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 646.0 kB/s  0:00:019.4 kB/s eta 0:00:01
# ...
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.1.1
#     Uninstalling msgpack-1.1.1:
#       Successfully uninstalled msgpack-1.1.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [fastf1]━━━━ 7/8 [fastf1]
# ...

# %%
python collect_f1_data.py --start-year 2022 --end-year 2024
# Out:
#   Cell In[3], line 1
#     python collect_f1_data.py --start-year 2022 --end-year 2024
#            ^
# SyntaxError: invalid syntax
